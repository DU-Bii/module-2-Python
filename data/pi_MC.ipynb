# %% [markdown]
# # Détermination du nombre $\pi$ par Monte-Carlo
#
# D'abord on importe les modules

# %%
import random
import math

import matplotlib.pyplot as plt

# %% [markdown]
# Ensuite on fait un essaie avec 100 itérations.

# %%
nb_iterations = 100
# On initialise notre compteur et on fixe la taille du graphe.
counts = 0
plt.figure(figsize=(5, 5))
# On boucle nb_iterations.
for i in range(0, nb_iterations):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    r = math.sqrt(x*x + y*y)
    if r <= 1:
        # Dans le cercle.
        counts += 1
        plt.scatter(x, y, color="red")
    else:
        # Hors du cercle.
        plt.scatter(x, y, color="blue")

# On imprime les résultats.
print("Nombre de points dans le carré : {}".format(nb_iterations))
print("Nombre de points dans le cercle : {}".format(counts))
pi_MC = counts/nb_iterations * 4
print("Évaluation de pi : {:.6f}".format(pi_MC))
print("Valeur de pi : {:.6f}".format(math.pi))
print("Différence : {:.6f}".format(pi_MC - math.pi))
# Out:
# Nombre de points dans le carré : 100
# Nombre de points dans le cercle : 86
# Évaluation de pi : 3.440000
# Valeur de pi : 3.141593
# Différence : 0.298407

# %% [markdown]
# On réessaie avec 1000 itérations !

# %%
nb_iterations = 1000
# On initialise notre compteur et on fixe la taille du graphe.
counts = 0
plt.figure(figsize=(5, 5))
# On boucle nb_iterations.
for i in range(0, nb_iterations):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    r = math.sqrt(x*x + y*y)
    if r <= 1:
        # Dans le cercle.
        counts += 1
        plt.scatter(x, y, color="red")
    else:
        # Hors du cercle.
        plt.scatter(x, y, color="blue")

# On imprime les résultats.
print("Nombre de points dans le carré : {}".format(nb_iterations))
print("Nombre de points dans le cercle : {}".format(counts))
pi_MC = counts/nb_iterations * 4
print("Évaluation de pi : {:.6f}".format(pi_MC))
print("Valeur de pi : {:.6f}".format(math.pi))
print("Différence : {:.6f}".format(pi_MC - math.pi))
# Out:
# Nombre de points dans le carré : 1000
# Nombre de points dans le cercle : 784
# Évaluation de pi : 3.136000
# Valeur de pi : 3.141593
# Différence : -0.005593

# %% [markdown]
# On essaie enfin avec 10000 itérations !

# %%
nb_iterations = 10000
# On initialise notre compteur et on fixe la taille du graphe.
counts = 0
plt.figure(figsize=(5, 5))
# On boucle nb_iterations.
for i in range(0, nb_iterations):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    r = math.sqrt(x*x + y*y)
    if r <= 1:
        # Dans le cercle.
        counts += 1
        plt.scatter(x, y, color="red")
    else:
        # Hors du cercle.
        plt.scatter(x, y, color="blue")

# On imprime les résultats.
print("Nombre de points dans le carré : {}".format(nb_iterations))
print("Nombre de points dans le cercle : {}".format(counts))
pi_MC = counts/nb_iterations * 4
print("Évaluation de pi : {:.6f}".format(pi_MC))
print("Valeur de pi : {:.6f}".format(math.pi))
print("Différence : {:.6f}".format(pi_MC - math.pi))
# Out:
# Nombre de points dans le carré : 10000
# Nombre de points dans le cercle : 7909
# Évaluation de pi : 3.163600
# Valeur de pi : 3.141593
# Différence : 0.022007

# %% [markdown]
# Et voilà :-) !
#
# Vous pourrez noter que nous avons dû répéter 3 fois le même code pour nos 3 tentatives avec 100, 1000 et 10000 itérations. Ce n'est bien sûr pas très joli, ni efficace. Pour écrire une seule fois le code qui fait le calcul et le faire fonctionner avec un nombre d'itérations différent, il faudrait utiliser les [fonctions](https://python.sdv.univ-paris-diderot.fr/09_fonctions/). Malheureusement, nous n'avons pas le temps d'aborder cette partie en 6 séances. Mais pour ceux qui veulent aller plus loin, n'hésitez pas à aller lire ce chapitre ainsi que le [chapitre avancé sur les fonctions](https://python.sdv.univ-paris-diderot.fr/12_plus_sur_les_fonctions/). Si vous souhaitez voir à quoi pourrait ressembler un tel notebook, vous pouvez aller jeter un coup d'oeil [ici](pi_MC_fonction.ipynb).
